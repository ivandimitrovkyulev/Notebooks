# %%
import warnings
warnings.filterwarnings('ignore')
import src.stlouisfed as fred

# %%
series = fred.search_series('inflation')

series.sort_values('popularity', ascending=False)
# Out:
#                  id realtime_start realtime_end  \
# 715        FEDFUNDS     2024-03-24   2024-03-24
# 16         CPIAUCSL     2024-03-24   2024-03-24
# 3            T10YIE     2024-03-24   2024-03-24
# 730             DFF     2024-03-24   2024-03-24
# 6    FPCPITOTLZGUSA     2024-03-24   2024-03-24
# ..              ...            ...          ...
# 874        WTP10L13     2024-03-24   2024-03-24
# 872        WTP10J14     2024-03-24   2024-03-24
# 871         TP10L17     2024-03-24   2024-03-24
# 870         TP10L18     2024-03-24   2024-03-24
# 873         TP10J17     2024-03-24   2024-03-24
#
#                                                  title observation_start  \
# 715                       Federal Funds Effective Rate        1954-07-01
# 16   Consumer Price Index for All Urban Consumers: ...        1947-01-01
# 3                     10-Year Breakeven Inflation Rate        2003-01-02
# 730                       Federal Funds Effective Rate        1954-07-01
# ...

# %%
data_1 = fred.get_series_observation("FEDFUNDS")
data_2 = fred.get_series_observation("UNRATE")

# %%
data_2
# Out:
#             lin
# date
# 1948-01-01  3.4
# 1948-02-01  3.8
# 1948-03-01  4.0
# 1948-04-01  3.9
# 1948-05-01  3.5
# ...         ...
# 2023-10-01  3.8
# 2023-11-01  3.7
# 2023-12-01  3.7
# 2024-01-01  3.7
# 2024-02-01  3.9
#
# [914 rows x 1 columns]

# %%
from src.plotting import plot_n_chart_comparison
plot_n_chart_comparison([("FEDFUNDS", data_1), ("UNRATE", data_2), ], y_axis='lin', log_scale=False)
# Out:
# FEDFUNDS / UNRATE correlation:0.06565395
