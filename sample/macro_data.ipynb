# %%
import warnings

warnings.filterwarnings("ignore")
import src.stlouisfed as fred

# %%
series = fred.search_series("inflation")

series.sort_values("popularity", ascending=False).head(10)
# Out:
#                        id realtime_start realtime_end  \
# 707              FEDFUNDS     2024-06-29   2024-06-29
# 16               CPIAUCSL     2024-06-29   2024-06-29
# 3                  T10YIE     2024-06-29   2024-06-29
# 721                   DFF     2024-06-29   2024-06-29
# 6          FPCPITOTLZGUSA     2024-06-29   2024-06-29
# 0                  DFII10     2024-06-29   2024-06-29
# 7    CORESTICKM159SFRBATL     2024-06-29   2024-06-29
# 8                   T5YIE     2024-06-29   2024-06-29
# 9                CPILFESL     2024-06-29   2024-06-29
# 14                 T5YIFR     2024-06-29   2024-06-29
#
#                                                  title observation_start  \
# 707                       Federal Funds Effective Rate        1954-07-01
# 16   Consumer Price Index for All Urban Consumers: ...        1947-01-01
# 3                     10-Year Breakeven Inflation Rate        2003-01-02
# 721                       Federal Funds Effective Rate        1954-07-01
# ...

# %%
name1 = "FEDFUNDS"
name2 = "GDP"
data1 = fred.get_series_observation(name1)
data2 = fred.get_series_observation(name2)

# %%
from src import utils, plotting

plotting.plot_n_chart_comparison(
    [
        (name1 + "% change", data1.pct_change()),
        (name2 + "% change", data2.pct_change()),
    ],
    log_scale=False,
)
# Out:
# FEDFUNDS% change / GDP% change correlation:0.37635780
# <module 'matplotlib.pyplot' from '/Users/ivankyulev/Projects/Notebooks/.venv/lib/python3.11/site-packages/matplotlib/pyplot.py'>

# %%
data1.pct_change().plot(), data2.pct_change().plot()
# Out:
# (<Axes: xlabel='Date'>, <Axes: xlabel='Date'>)

# %%
data2.dropna()
# Out:
#                 Close
# Date
# 1947-01-01    243.164
# 1947-04-01    245.968
# 1947-07-01    249.585
# 1947-10-01    259.745
# 1948-01-01    265.742
# ...               ...
# 2023-01-01  26813.601
# 2023-04-01  27063.012
# 2023-07-01  27610.128
# 2023-10-01  27956.998
# 2024-01-01  28269.174
#
# [309 rows x 1 columns]
