# %%
import yfinance as yf
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
bp = yf.Ticker("BP.L")

# %%
bp.info
# Out:
# {'address1': "1 St James's Square",
#  'city': 'London',
#  'zip': 'SW1Y 4PD',
#  'country': 'United Kingdom',
#  'phone': '44 20 7496 4000',
#  'fax': '44 20 7496 4630',
#  'website': 'https://www.bp.com',
#  'industry': 'Oil & Gas Integrated',
#  'industryKey': 'oil-gas-integrated',
#  'industryDisp': 'Oil & Gas Integrated',
#  'sector': 'Energy',
#  'sectorKey': 'energy',
#  'sectorDisp': 'Energy',
#  'longBusinessSummary': 'BP p.l.c. provides carbon products and services. The company operates through Gas & Low Carbon Energy, Oil Production & Operations, and Customers & Products segments. It engages in the production of natural gas, and integrated gas and power; trading of gas; operation of onshore and offshore wind power, as well as hydrogen and carbon capture and storage facilities; trading and marketing of renewable and non-renewable power; and production of crude oil. In addition, the company involved in convenience and retail fuel, EV charging, Castrol lubricant, aviation, B2B, and midstream businesses; refining and oil trading; and bioenergy business. Further, it engages in power and storage, digital transformation, carbon management, and bio and low carbon related products, as well as energy and environmental commodities and mobility businesses. The company was founded in 1908 and is headquartered in London, the United Kingdom.',
#  'fullTimeEmployees': 67600,
#  'companyOfficers': [{'maxAge': 1,
#    'name': 'Mr. Murray  Auchincloss',
#    'age': 52,
#    'title': 'Interim CEO & Director',
#    'yearBorn': 1970,
#    'fiscalYear': 2022,
#    'totalPay': 2391000,
#    'exercisedValue': 0,
#    'unexercisedValue': 0},
#   {'maxAge': 1,
#    'name': 'Ms. Katherine Anne Thomson',
#    'age': 54,
#    'title': 'Senior VP of Finance for Production & Operations and Interim CFO',
#    'yearBorn': 1968,
#    'fiscalYear': 2022,
#    'exercisedValue': 0,
#    'unexercisedValue': 0},
#   {'maxAge': 1,
#    'name': 'Mr. Gordon  Birrell',
#    'age': 59,
#    'title': 'Executive Vice President of Production & Operations',
#    'yearBorn': 1963,
#    'fiscalYear': 2022,
#    'exercisedValue': 0,
#    'unexercisedValue': 0},
#   {'maxAge': 1,
#    'name': 'Mr. Craig  Marshall',
#    'title': 'Group Head of Investor Relations',
#    'fiscalYear': 2022,
#    'exercisedValue': 0,
#    'unexercisedValue': 0},
#   {'maxAge': 1,
#    'name': 'Mr. Eric  Nitcher',
#    'age': 59,
#    'title': 'Executive Vice President of Legal',
#    'yearBorn': 1963,
#    'fiscalYear': 2022,
#    'exercisedValue': 0,
#    'unexercisedValue': 0},
#   {'maxAge': 1,
#    'name': 'Mr. Rahul  Saxena',
#    'title': 'Group Ethics & Compliance Officer',
#    'fiscalYear': 2022,
#    'exercisedValue': 0,
#    'unexercisedValue': 0},
#   {'maxAge': 1,
#    'name': 'Mr. Marco  Ryan',
#    'title': 'Senior Vice President of Digital Customers & Markets',
#    'fiscalYear': 2022,
#    'exercisedValue': 0,
#    'unexercisedValue': 0},
#   {'maxAge': 1,
#    'name': 'Ms. Kerry  Dryburgh',
#    'title': 'Executive Vice President of People & Culture',
#    'fiscalYear': 2022,
#    'exercisedValue': 0,
#    'unexercisedValue': 0},
#   {'maxAge': 1,
#    'name': 'Mr. Richard M. Hookway',
#    'age': 61,
#    'title': 'Chief Operating Officer of Global Business Services & Information Technology and Systems',
#    'yearBorn': 1961,
#    'fiscalYear': 2022,
#    'exercisedValue': 0,
#    'unexercisedValue': 0},
#   {'maxAge': 1,
#    'name': 'Dr. Helmut  Schuster',
#    'age': 61,
#    'title': 'Advisor',
#    'yearBorn': 1961,
#    'fiscalYear': 2022,
#    'exercisedValue': 0,
#    'unexercisedValue': 0}],
#  'auditRisk': 5,
#  'boardRisk': 1,
#  'compensationRisk': 5,
#  'shareHolderRightsRisk': 9,
#  'overallRisk': 3,
#  'governanceEpochDate': 1701388800,
#  'compensationAsOfEpochDate': 1672444800,
#  'maxAge': 86400,
#  'priceHint': 2,
#  'previousClose': 465.9,
#  'open': 470.1,
#  'dayLow': 456.8,
#  'dayHigh': 471.95,
#  'regularMarketPreviousClose': 465.9,
#  'regularMarketOpen': 470.1,
#  'regularMarketDayLow': 456.8,
#  'regularMarketDayHigh': 471.95,
#  'dividendRate': 0.22,
#  'dividendYield': 0.048800003,
#  'exDividendDate': 1699488000,
#  'payoutRatio': 0.1906,
#  'fiveYearAvgDividendYield': 6.12,
#  'beta': 0.569,
#  'trailingPE': 4.200459,
#  'forwardPE': 594.6104,
#  'volume': 87508040,
#  'regularMarketVolume': 87508040,
#  'averageVolume': 44005477,
#  'averageVolume10days': 47038352,
#  'averageDailyVolume10Day': 47038352,
#  'bid': 455.0,
#  'ask': 463.5,
#  'bidSize': 0,
#  'askSize': 0,
#  'marketCap': 77855105024,
#  'fiftyTwoWeekLow': 447.2,
#  'fiftyTwoWeekHigh': 570.567,
#  'priceToSalesTrailing12Months': 0.34444895,
#  'fiftyDayAverage': 495.741,
#  'twoHundredDayAverage': 493.4375,
#  'trailingAnnualDividendRate': 0.278,
#  'trailingAnnualDividendYield': 0.0005966946,
#  'currency': 'GBp',
#  'enterpriseValue': 122859749376,
#  'profitMargins': 0.113570005,
#  'floatShares': 16811021359,
#  'sharesOutstanding': 16969499648,
#  'heldPercentInsiders': 0.00294,
#  'heldPercentInstitutions': 0.39568,
#  'impliedSharesOutstanding': 17600999424,
#  'bookValue': 4.209,
#  'priceToBook': 108.77881,
#  'lastFiscalYearEnd': 1672444800,
#  'nextFiscalYearEnd': 1703980800,
#  'mostRecentQuarter': 1696032000,
#  'netIncomeToCommon': 25670000640,
#  'trailingEps': 1.09,
#  'forwardEps': 0.77,
#  'pegRatio': -7.64,
#  'lastSplitFactor': '2:1',
#  'lastSplitDate': 938995200,
#  'enterpriseToRevenue': 0.544,
#  'enterpriseToEbitda': 2.062,
#  '52WeekChange': -0.018752694,
#  'SandP52WeekChange': 0.23614728,
#  'lastDividendValue': 5.7367,
#  'lastDividendDate': 1699488000,
#  'exchange': 'LSE',
#  'quoteType': 'EQUITY',
#  'symbol': 'BP.L',
#  'underlyingSymbol': 'BP.L',
#  'shortName': 'BP PLC $0.25',
#  'longName': 'BP p.l.c.',
#  'firstTradeDateEpochUtc': 583743600,
#  'timeZoneFullName': 'Europe/London',
#  'timeZoneShortName': 'GMT',
#  'uuid': 'f367e74b-06ae-3c13-9f8a-f5b4b43b117c',
#  'messageBoardId': 'finmb_394466',
#  'currentPrice': 457.85,
#  'targetHighPrice': 9.94,
#  'targetLowPrice': 4.97,
#  'targetMeanPrice': 6.11,
#  'targetMedianPrice': 5.97,
#  'recommendationMean': 2.1,
#  'recommendationKey': 'buy',
#  'numberOfAnalystOpinions': 21,
#  'totalCash': 30858000384,
#  'totalCashPerShare': 1.794,
#  'ebitda': 59592998912,
#  'totalDebt': 59689000960,
#  'quickRatio': 0.737,
#  'currentRatio': 1.208,
#  'totalRevenue': 226027995136,
#  'debtToEquity': 68.079,
#  'revenuePerShare': 12.773,
#  'returnOnAssets': 0.103149995,
#  'returnOnEquity': 0.33048,
#  'grossProfits': 70171000000,
#  'freeCashflow': 17658875904,
#  'operatingCashflow': 36232998912,
#  'revenueGrowth': -0.029,
#  'grossMargins': 0.34346,
#  'ebitdaMargins': 0.26365,
#  'operatingMargins': 0.15419,
#  'financialCurrency': 'USD',
#  'trailingPegRatio': None}

# %%
# get historical market data
hist = bp.history(period="20y")

# %%
# plot
hist.describe()
# Out:
#        Open  High   Low  Close      Volume  Dividends  Stock Splits
# count 5,066 5,066 5,066  5,066       5,066      5,066         5,066
# mean    281   284   278    281  48,058,112          0             0
# std      81    82    80     81  30,192,823          1             0
# min     145   149     4    147           0          0             0
# 25%     227   230   225    227  27,959,642          0             0
# 50%     253   255   250    253  39,458,718          0             0
# 75%     316   318   313    316  60,041,455          0             0
# max     552   556   547    551 359,712,224         10             0

# %%
pd.set_option('display.float_format', '{:,.0f}'.format)
hist
# Out:
#                            Open  High  Low  Close    Volume  Dividends  \
# Date
# 2003-12-15 00:00:00+00:00   162   162  159    160  41080860          0
# 2003-12-16 00:00:00+00:00   159   161  158    159  46129868          0
# 2003-12-17 00:00:00+00:00   160   163  158    161  73135387          0
# 2003-12-18 00:00:00+00:00   162   166  161    165  99806240          0
# 2003-12-19 00:00:00+00:00   165   168  165    167  73169464          0
# ...                         ...   ...  ...    ...       ...        ...
# 2023-12-11 00:00:00+00:00   469   472  464    467  35796728          0
# 2023-12-12 00:00:00+00:00   467   471  461    461  38314237          0
# 2023-12-13 00:00:00+00:00   459   464  457    460  69403048          0
# 2023-12-14 00:00:00+00:00   462   471  457    466  52321651          0
# 2023-12-15 00:00:00+00:00   470   472  457    458  96522587          0
#
#                            Stock Splits
# Date
# 2003-12-15 00:00:00+00:00             0
# 2003-12-16 00:00:00+00:00             0
# 2003-12-17 00:00:00+00:00             0
# 2003-12-18 00:00:00+00:00             0
# 2003-12-19 00:00:00+00:00             0
# ...                                 ...
# 2023-12-11 00:00:00+00:00             0
# 2023-12-12 00:00:00+00:00             0
# 2023-12-13 00:00:00+00:00             0
# 2023-12-14 00:00:00+00:00             0
# 2023-12-15 00:00:00+00:00             0
#
# [5066 rows x 7 columns]

# %%
hist['Volume'].plot(logy=True)
# Out:
# <Axes: xlabel='Date'>

# %%
pd.set_option('display.float_format', '{:,.0f}'.format)
bp.cash_flow
# Out:
#                                            2022-12-31      2021-12-31  \
# Free Cash Flow                         28,863,000,000  12,725,000,000
# Repurchase Of Capital Stock            -9,996,000,000  -3,151,000,000
# Repayment Of Debt                     -11,697,000,000 -16,804,000,000
# Issuance Of Debt                        2,013,000,000   6,987,000,000
# Capital Expenditure                   -12,069,000,000 -10,887,000,000
# End Cash Position                      29,195,000,000  30,681,000,000
# Beginning Cash Position                30,681,000,000  31,111,000,000
# Effect Of Exchange Rate Changes          -684,000,000    -269,000,000
# Changes In Cash                          -802,000,000    -161,000,000
# Financing Cash Flow                   -28,021,000,000 -18,079,000,000
# Net Other Financing Charges              -336,000,000     509,000,000
# Cash Dividends Paid                    -4,358,000,000  -4,304,000,000
# Common Stock Dividend Paid             -4,358,000,000             NaN
# Net Common Stock Issuance              -9,996,000,000  -3,151,000,000
# Common Stock Payments                  -9,996,000,000  -3,151,000,000
# Net Issuance Payments Of Debt         -11,076,000,000  -8,740,000,000
# Net Short Term Debt Issuance           -1,392,000,000   1,077,000,000
# Short Term Debt Issuance                          NaN             NaN
# Net Long Term Debt Issuance            -9,684,000,000  -9,817,000,000
# Long Term Debt Payments               -11,697,000,000 -16,804,000,000
# Long Term Debt Issuance                 2,013,000,000   6,987,000,000
# Investing Cash Flow                   -13,713,000,000  -5,694,000,000
# Net Other Investing Changes                       NaN             NaN
# Net Business Purchase And Sale         -2,420,000,000   3,851,000,000
# Sale Of Business                        1,841,000,000   5,812,000,000
# Purchase Of Business                   -4,261,000,000  -1,961,000,000
# Net PPE Purchase And Sale                 709,000,000   1,145,000,000
# Sale Of PPE                               709,000,000   1,145,000,000
# Purchase Of PPE                                   NaN -10,887,000,000
# Capital Expenditure Reported          -12,069,000,000 -10,887,000,000
# Operating Cash Flow                    40,932,000,000  23,612,000,000
# Taxes Refund Paid                     -10,106,000,000  -4,179,000,000
# Interest Received Cfo                     414,000,000     320,000,000
# Interest Paid Cfo                      -2,208,000,000  -2,474,000,000
# Dividend Received Cfo                   1,700,000,000   1,842,000,000
# Change In Working Capital              -6,270,000,000    -626,000,000
# Change In Other Current Liabilities    17,806,000,000  20,095,000,000
# Change In Other Current Assets        -18,584,000,000 -13,263,000,000
# Change In Inventory                    -5,492,000,000    -626,000,000
# Other Non Cash Items                      396,000,000     466,000,000
# Stock Based Compensation                  795,000,000     627,000,000
# Provisionand Write Offof Assets           440,000,000   2,934,000,000
# Depreciation And Amortization          14,703,000,000  14,972,000,000
# Depreciation                           14,703,000,000  14,972,000,000
# Pension And Employee Benefit Expense     -257,000,000    -655,000,000
# Gain Loss On Investment Securities         43,000,000             NaN
# Net Income From Continuing Operations  15,405,000,000  15,227,000,000
#
#                                            2020-12-31      2019-12-31
# Free Cash Flow                           -144,000,000  10,352,000,000
# Repurchase Of Capital Stock              -776,000,000  -1,511,000,000
# Repayment Of Debt                     -12,179,000,000  -7,118,000,000
# Issuance Of Debt                       14,736,000,000   8,777,000,000
# Capital Expenditure                   -12,306,000,000 -15,418,000,000
# End Cash Position                      31,111,000,000  22,472,000,000
# Beginning Cash Position                22,472,000,000  22,468,000,000
# Effect Of Exchange Rate Changes           379,000,000      25,000,000
# Changes In Cash                         8,260,000,000     -21,000,000
# Financing Cash Flow                     3,956,000,000  -8,817,000,000
# Net Other Financing Charges            12,429,000,000     566,000,000
# Cash Dividends Paid                    -6,340,000,000  -6,946,000,000
# Common Stock Dividend Paid             -6,340,000,000  -6,946,000,000
# Net Common Stock Issuance                -776,000,000  -1,511,000,000
# Common Stock Payments                    -776,000,000  -1,511,000,000
# Net Issuance Payments Of Debt           1,323,000,000   1,659,000,000
# Net Short Term Debt Issuance           -1,234,000,000     180,000,000
# Short Term Debt Issuance                          NaN     180,000,000
# Net Long Term Debt Issuance             2,557,000,000   1,479,000,000
# Long Term Debt Payments               -12,179,000,000  -7,118,000,000
# Long Term Debt Issuance                14,736,000,000   8,597,000,000
# Investing Cash Flow                    -7,858,000,000 -16,974,000,000
# Net Other Investing Changes                       NaN     500,000,000
# Net Business Purchase And Sale          3,240,000,000  -2,302,000,000
# Sale Of Business                        4,989,000,000   1,701,000,000
# Purchase Of Business                   -1,749,000,000  -4,003,000,000
# Net PPE Purchase And Sale                 491,000,000     500,000,000
# Sale Of PPE                               491,000,000     500,000,000
# Purchase Of PPE                       -12,306,000,000 -15,418,000,000
# Capital Expenditure Reported          -12,306,000,000 -15,418,000,000
# Operating Cash Flow                    12,162,000,000  25,770,000,000
# Taxes Refund Paid                      -2,438,000,000  -5,437,000,000
# Interest Received Cfo                      74,000,000     416,000,000
# Interest Paid Cfo                      -2,728,000,000  -2,870,000,000
# Dividend Received Cfo                   1,442,000,000   1,962,000,000
# Change In Working Capital                 -85,000,000  -2,918,000,000
# Change In Other Current Liabilities    -8,278,000,000   2,823,000,000
# Change In Other Current Assets          4,230,000,000  -2,335,000,000
# Change In Inventory                     3,963,000,000  -2,918,000,000
# Other Non Cash Items                    2,857,000,000     657,000,000
# Stock Based Compensation                  723,000,000     730,000,000
# Provisionand Write Offof Assets           735,000,000    -176,000,000
# Depreciation And Amortization          14,889,000,000  18,411,000,000
# Depreciation                           14,889,000,000  18,411,000,000
# Pension And Employee Benefit Expense       33,000,000    -238,000,000
# Gain Loss On Investment Securities                NaN             NaN
# Net Income From Continuing Operations -24,888,000,000   8,154,000,000
