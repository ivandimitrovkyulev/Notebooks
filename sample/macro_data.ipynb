# %%
import warnings
warnings.filterwarnings('ignore')
import src.stlouisfed as fred

# %%
series = fred.search_series('stock')

series.sort_values('popularity', ascending=False).head(10)
# Out:
#                   id realtime_start realtime_end  \
# 0               M2SL     2024-03-26   2024-03-26
# 1              WM2NS     2024-03-26   2024-03-26
# 3               M1SL     2024-03-26   2024-03-26
# 28             SP500     2024-03-26   2024-03-26
# 5                M2V     2024-03-26   2024-03-26
# 856         BOGMBASE     2024-03-26   2024-03-26
# 7             M2REAL     2024-03-26   2024-03-26
# 34            VIXCLS     2024-03-26   2024-03-26
# 38              DJIA     2024-03-26   2024-03-26
# 8    MABMM301USM189S     2024-03-26   2024-03-26
#
#                                                  title observation_start  \
# 0                                                   M2        1959-01-01
# 1                                                   M2        1980-11-03
# 3                                                   M1        1959-01-01
# 28                                             S&P 500        2014-03-26
# ...

# %%
data_1 = fred.get_series_observation("VIXCLS")
data_2 = fred.get_series_observation("UNRATE")

# %%
from src.plotting import plot_n_chart_comparison
plot_n_chart_comparison([("VIXCLS", data_1), ("UNRATE", data_2), ], y_axis='lin', log_scale=False)
# Out:
# VIXCLS / UNRATE correlation:0.29633662
