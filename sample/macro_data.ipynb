# %%
import warnings
warnings.filterwarnings('ignore')
import src.stlouisfed as fred

# %%
series = fred.search_series('commodity')

series.sort_values('popularity', ascending=False).head(10)
# Out:
#                id realtime_start realtime_end  \
# 0          PPIACO     2024-04-10   2024-04-10
# 16     DCOILWTICO     2024-04-10   2024-04-10
# 1         WPU0911     2024-04-10   2024-04-10
# 5       WPU101707     2024-04-10   2024-04-10
# 40   DCOILBRENTEU     2024-04-10   2024-04-10
# 80        GASREGW     2024-04-10   2024-04-10
# 7     WPU10170502     2024-04-10   2024-04-10
# 124        PPIFIS     2024-04-10   2024-04-10
# 10         WPU061     2024-04-10   2024-04-10
# 21          WPU10     2024-04-10   2024-04-10
#
#                                                  title observation_start  \
# 0    Producer Price Index by Commodity: All Commodi...        1913-01-01
# 16   Crude Oil Prices: West Texas Intermediate (WTI...        1986-01-02
# 1    Producer Price Index by Commodity: Pulp, Paper...        1926-01-01
# 5    Producer Price Index by Commodity: Metals and ...        1982-06-01
# 40                    Crude Oil Prices: Brent - Europe        1987-05-20
# 80               US Regular All Formulations Gas Price        1990-08-20
# 7    Producer Price Index by Commodity: Metals and ...        2010-12-01
# 124    Producer Price Index by Commodity: Final Demand        2009-11-01
# 10   Producer Price Index by Commodity: Chemicals a...        1933-01-01
# 21   Producer Price Index by Commodity: Metals and ...        1926-01-01
#
#     observation_end              frequency frequency_short  \
# 0        2024-02-01                Monthly               M
# 16       2024-04-08                  Daily               D
# 1        2024-02-01                Monthly               M
# 5        2024-02-01                Monthly               M
# 40       2024-04-08                  Daily               D
# 80       2024-04-08  Weekly, Ending Monday               W
# 7        2023-07-01                Monthly               M
# 124      2024-02-01                Monthly               M
# 10       2024-02-01                Monthly               M
# 21       2024-02-01                Monthly               M
#
#                   units         units_short      seasonal_adjustment  \
# 0        Index 1982=100      Index 1982=100  Not Seasonally Adjusted
# 16   Dollars per Barrel        $ per Barrel  Not Seasonally Adjusted
# 1        Index 1982=100      Index 1982=100  Not Seasonally Adjusted
# 5    Index Jun 1982=100  Index Jun 1982=100  Not Seasonally Adjusted
# 40   Dollars per Barrel        $ per Barrel  Not Seasonally Adjusted
# 80   Dollars per Gallon        $ per Gallon  Not Seasonally Adjusted
# 7    Index Dec 2010=100  Index Dec 2010=100  Not Seasonally Adjusted
# 124  Index Nov 2009=100  Index Nov 2009=100      Seasonally Adjusted
# 10       Index 1982=100      Index 1982=100  Not Seasonally Adjusted
# 21       Index 1982=100      Index 1982=100  Not Seasonally Adjusted
#
#     seasonal_adjustment_short            last_updated  popularity  \
# 0                         NSA  2024-03-14 07:53:02-05          78
# 16                        NSA  2024-04-10 13:56:06-05          77
# 1                         NSA  2024-03-14 07:52:02-05          75
# 5                         NSA  2024-03-14 07:51:02-05          71
# 40                        NSA  2024-04-10 13:56:05-05          70
# 80                        NSA  2024-04-10 10:23:02-05          69
# 7                         NSA  2023-08-11 07:51:02-05          68
# 124                        SA  2024-03-14 07:53:03-05          64
# 10                        NSA  2024-03-14 07:52:02-05          64
# 21                        NSA  2024-03-14 07:51:03-05          63
#
#      group_popularity                                              notes
# 0                  78                                                NaN
# 16                 78  Definitions, Sources and Explanatory Notes (ht...
# 1                  76                                                NaN
# 5                  72                                                NaN
# 40                 73  Definitions, Sources and Explanatory Notes (ht...
# 80                 69  Weighted average based on sampling of approxim...
# 7                  68                                                NaN
# 124                64                                                NaN
# 10                 65                                                NaN
# 21                 63                                                NaN

# %%
data_1_name = "CPIAUCSL"
data_2_name = "PPIACO"
data_1 = fred.get_series_observation(data_1_name)
data_2 = fred.get_series_observation(data_2_name)

# %%
# from src import utils, plotting
plotting.plot_n_chart_comparison([(data_1_name, data_1.iloc[710::]), (data_2_name, data_2.iloc[1120::]), ], log_scale=False)
# Out:
# CPIAUCSL / PPIACO correlation:0.89497078

# %%
data_1.plot(figsize=(20, 9))
# Out:
# <Axes: xlabel='Date'>
