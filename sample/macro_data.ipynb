# %%
import warnings
warnings.filterwarnings('ignore')
import src.stlouisfed as fred

# %%
series = fred.search_series('GDP')

series.sort_values('popularity', ascending=False).head(10)
# Out:
#                   id realtime_start realtime_end  \
# 4                GDP     2024-04-16   2024-04-16
# 8              GDPC1     2024-04-16   2024-04-16
# 0        GFDEGDQ188S     2024-04-16   2024-04-16
# 565           PAYEMS     2024-04-16   2024-04-16
# 601              M2V     2024-04-16   2024-04-16
# 31   A939RX0Q048SBEA     2024-04-16   2024-04-16
# 34   A091RC1Q027SBEA     2024-04-16   2024-04-16
# 1        FYFSGDA188S     2024-04-16   2024-04-16
# 37            GDPPOT     2024-04-16   2024-04-16
# 30            GDPDEF     2024-04-16   2024-04-16
#
#                                                  title observation_start  \
# 4                               Gross Domestic Product        1947-01-01
# 8                          Real Gross Domestic Product        1947-01-01
# 0    Federal Debt: Total Public Debt as Percent of ...        1966-01-01
# 565                       All Employees, Total Nonfarm        1939-01-01
# ...

# %%
data_1_name = "CPIAUCSL"
data_2_name = "GDP"
data_1 = fred.get_series_observation(data_1_name)
data_2 = fred.get_series_observation(data_2_name)

# %%
from src import utils, plotting
plotting.plot_n_chart_comparison([(data_2_name, data_2), ], log_scale=False)

# %%
data_2.plot(figsize=(20, 9))
# Out:
# <Axes: xlabel='Date'>
